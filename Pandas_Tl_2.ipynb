# %% [markdown]
# <a href="https://colab.research.google.com/github/Aflah3100/Pandas-Tutorial/blob/main/Pandas_Tl_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataframe=pd.read_csv('IMDB-Movie-Data.csv')

# %%
#Printing the information
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#Printing first 5 rows
dataframe.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Guardians of the Galaxy</td>
#       <td>Action,Adventure,Sci-Fi</td>
#       <td>A group of intergalactic criminals are forced ...</td>
#       <td>James Gunn</td>
# ...

# %%
#Pringing the last 5 rows
dataframe.tail(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>995</th>
#       <td>996</td>
#       <td>Secret in Their Eyes</td>
#       <td>Crime,Drama,Mystery</td>
#       <td>A tight-knit team of rising investigators, alo...</td>
#       <td>Billy Ray</td>
# ...

# %%
#Printing the shape
dataframe.shape
# Out:
# (1000, 12)

# %%
#Printing the headers
dataframe.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#Printing first column

dataframe['Rank']
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: Rank, Length: 1000, dtype: int64

# %%
#Printing the first 2 columns
dataframe[['Rank','Title']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Guardians of the Galaxy</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Prometheus</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Split</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Sing</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Suicide Squad</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
# ...

# %%
#Printing the first row

dataframe.iloc[0]
# Out:
# Rank                                                                  1
# Title                                           Guardians of the Galaxy
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: 0, dtype: object

# %%
#Printing the first 2 rows

dataframe.iloc[0:2]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Guardians of the Galaxy</td>
#       <td>Action,Adventure,Sci-Fi</td>
#       <td>A group of intergalactic criminals are forced ...</td>
#       <td>James Gunn</td>
# ...

# %%
#Printing a specific row and column

dataframe.iloc[1,4]
# Out:
# 'Ridley Scott'

# %%
#Iterating through the rows:

for index,row in dataframe.iterrows():
    print(index,row)
# Out:
# 0 Rank                                                                  1
# Title                                           Guardians of the Galaxy
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: 0, dtype: object
# 1 Rank                                                                  2
# ...

# %%
#Printing details based on conditions
dataframe.loc[dataframe['Rating']>8.5]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>36</th>
#       <td>37</td>
#       <td>Interstellar</td>
#       <td>Adventure,Drama,Sci-Fi</td>
#       <td>A team of explorers travel through a wormhole ...</td>
#       <td>Christopher Nolan</td>
# ...

# %%
#Sorting values in the dataframe

tempdata=dataframe.loc[dataframe['Rating']>8.5]

tempdata.sort_values(['Rank'],ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>249</th>
#       <td>250</td>
#       <td>The Intouchables</td>
#       <td>Biography,Comedy,Drama</td>
#       <td>After he becomes a quadriplegic from a paragli...</td>
#       <td>Olivier Nakache</td>
# ...

# %%
#Describing the dataframe

dataframe.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1000.000000</td>
#       <td>1000.000000</td>
#       <td>1000.000000</td>
#       <td>1000.000000</td>
#       <td>1.000000e+03</td>
#       <td>872.000000</td>
#       <td>936.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>500.500000</td>
#       <td>2012.783000</td>
#       <td>113.172000</td>
#       <td>6.723200</td>
# ...

# %%
#Creating a column

dataframe['My rating']=dataframe.iloc[:,8]*1000

dataframe.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#       <th>My rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Guardians of the Galaxy</td>
#       <td>Action,Adventure,Sci-Fi</td>
#       <td>A group of intergalactic criminals are forced ...</td>
#       <td>James Gunn</td>
# ...

# %%
dataframe.groupby(['Rating']).sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#       <th>My rating</th>
#     </tr>
#     <tr>
#       <th>Rating</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1.9</th>
#       <td>830</td>
#       <td>2008</td>
#       <td>87</td>
#       <td>77207</td>
#       <td>14.17</td>
#       <td>15.0</td>
#       <td>1900.0</td>
#     </tr>
#     <tr>
# ...

# %%
#To find null value

dataframe.isnull()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#       <th>My rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
# ...

# %%
dataframe.dropna(axis=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#       <th>My rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Guardians of the Galaxy</td>
#       <td>Action,Adventure,Sci-Fi</td>
#       <td>A group of intergalactic criminals are forced ...</td>
#       <td>James Gunn</td>
# ...

# %%
#Renaming columns

dataframe.rename(columns={"My rating":"Per Rating"})

#dataframe.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Genre</th>
#       <th>Description</th>
#       <th>Director</th>
#       <th>Actors</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#       <th>Per Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Guardians of the Galaxy</td>
#       <td>Action,Adventure,Sci-Fi</td>
#       <td>A group of intergalactic criminals are forced ...</td>
#       <td>James Gunn</td>
# ...

# %%
#Correlating the attributes

dataframe.corr()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Year</th>
#       <th>Runtime (Minutes)</th>
#       <th>Rating</th>
#       <th>Votes</th>
#       <th>Revenue (Millions)</th>
#       <th>Metascore</th>
#       <th>My rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Rank</th>
#       <td>1.000000</td>
#       <td>-0.261605</td>
#       <td>-0.221739</td>
#       <td>-0.219555</td>
#       <td>-0.283876</td>
#       <td>-0.271592</td>
#       <td>-0.191869</td>
#       <td>-0.219555</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>-0.261605</td>
#       <td>1.000000</td>
#       <td>-0.164900</td>
# ...
